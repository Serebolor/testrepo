# %% [markdown]
# # **SpaceX  Falcon 9 First Stage Landing Prediction**

# %% [markdown]
# In this assignment, we will predict if the Falcon 9 first stage will land successfully. SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars; other providers cost upward of 165 million dollars each, much of the savings is due to the fact that SpaceX can reuse the first stage.
#
# In this lab, you will perform Exploratory Data Analysis and Feature Engineering.

# %% [markdown]
# ## Objectives
#
# Perform exploratory Data Analysis and Feature Engineering using `Pandas` and `Matplotlib`
#
# *   Exploratory Data Analysis
# *   Preparing Data  Feature Engineering

# %%
import pandas as pd

# %%
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/dataset_part_2.csv"
df=pd.read_csv(URL)
df.head(5)
# Out:
#    FlightNumber        Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1  2010-06-04       Falcon 9  6104.959412   LEO  CCAFS SLC 40
# 1             2  2012-05-22       Falcon 9   525.000000   LEO  CCAFS SLC 40
# 2             3  2013-03-01       Falcon 9   677.000000   ISS  CCAFS SLC 40
# 3             4  2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5  2013-12-03       Falcon 9  3170.000000   GTO  CCAFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0    None None        1     False   False  False        NaN    1.0
# 1    None None        1     False   False  False        NaN    1.0
# 2    None None        1     False   False  False        NaN    1.0
# 3  False Ocean        1     False   False  False        NaN    1.0
# 4    None None        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial   Longitude   Latitude  Class
# 0            0  B0003  -80.577366  28.561857      0
# 1            0  B0005  -80.577366  28.561857      0
# 2            0  B0007  -80.577366  28.561857      0
# 3            0  B1003 -120.610829  34.632093      0
# 4            0  B1004  -80.577366  28.561857      0

# %% [markdown]
# First, let's try to see how the `FlightNumber` (indicating the continuous launch attempts.) and `Payload` variables would affect the launch outcome.
#
# We can plot out the <code>FlightNumber</code> vs. <code>PayloadMass</code>and overlay the outcome of the launch. We see that as the flight number increases, the first stage is more likely to land successfully. The payload mass also appears to be a factor; even with more massive payloads, the first stage often returns successfully.

# %%
# pandas is a software library written for the Python programming language for data manipulation and analysis.
import pandas as pd
#NumPy is a library for the Python programming language, adding support for large, multi-dimensional arrays and matrices, along with a large collection of high-level mathematical functions to operate on these arrays
import numpy as np
# Matplotlib is a plotting library for python and pyplot gives us a MatLab like plotting framework. We will use this in our plotter function to plot data.
import matplotlib.pyplot as plt
#Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics
import seaborn as sns

# %%
sns.catplot(y="PayloadMass", x="FlightNumber", hue="Class", data=df, aspect = 5)
plt.xlabel("Flight Number",fontsize=20)
plt.ylabel("Pay load Mass (kg)",fontsize=20)
plt.show()

# %% [markdown]
# ### TASK 1: Visualize the relationship between Flight Number and Launch Site

# %% [markdown]
# Use the function <code>catplot</code> to plot <code>FlightNumber</code> vs <code>LaunchSite</code>, set the  parameter <code>x</code>  parameter to <code>FlightNumber</code>,set the  <code>y</code> to <code>Launch Site</code> and set the parameter <code>hue</code> to <code>'class'</code>

# %%
sns.catplot(y="LaunchSite", x="FlightNumber", hue="Class", data=df, aspect = 5)
plt.xlabel("Flight Number",fontsize=20)
plt.ylabel("LaunchSite",fontsize=20)
plt.show()

# %% [markdown]
# ### TASK 2: Visualize the relationship between Payload Mass and Launch Site

# %% [markdown]
# We also want to observe if there is any relationship between launch sites and their payload mass.

# %%
sns.catplot(y="LaunchSite", x="PayloadMass", hue="Class", data=df, aspect = 5)
plt.xlabel("Payload Mass",fontsize=20)
plt.ylabel("LaunchSite",fontsize=20)
plt.show()

# %% [markdown]
# Now if you observe Payload Mass Vs. Launch Site scatter point chart you will find for the VAFB-SLC  launchsite there are no  rockets  launched for  heavypayload mass(greater than 10000).

# %% [markdown]
# ### TASK  3: Visualize the relationship between success rate of each orbit type

# %% [markdown]
# Next, we want to visually check if there are any relationship between success rate and orbit type.
# Let's create a `bar chart` for the sucess rate of each orbit

# %%
# HINT use groupby method on Orbit column and get the mean of Class column
barchart = df.groupby('Orbit')['Class'].mean().reset_index()
barchart
# Out:
#     Orbit     Class
# 0   ES-L1  1.000000
# 1     GEO  1.000000
# 2     GTO  0.518519
# 3     HEO  1.000000
# 4     ISS  0.619048
# 5     LEO  0.714286
# 6     MEO  0.666667
# 7      PO  0.666667
# 8      SO  0.000000
# 9     SSO  1.000000
# 10   VLEO  0.857143

# %%
fig = plt.figure(figsize = (10,6))
ax = sns.barplot(data=barchart, x='Orbit', y='Class', color='skyblue')
ax.bar_label(ax.containers[0])
ax.set_title('Success rate depending on Orbit')
ax.set_ylabel('Success rate')
ax.set_xlabel('Orbit')
# Out:
# Text(0.5, 0, 'Orbit')

# %% [markdown]
# ### TASK  4: Visualize the relationship between FlightNumber and Orbit type

# %% [markdown]
# For each orbit, we want to see if there is any relationship between FlightNumber and Orbit type.

# %%
# Plot a scatter point chart with x axis to be FlightNumber and y axis to be the Orbit, and hue to be the class value
sns.catplot(y="Orbit", x="FlightNumber", hue="Class", data=df, aspect = 5)
plt.xlabel("Fligh tNumber",fontsize=20)
plt.ylabel("Orbit",fontsize=20)
plt.grid()
plt.show()

# %% [markdown]
# ### TASK  5: Visualize the relationship between Payload Mass and Orbit type

# %% [markdown]
# With heavy payloads the successful landing or positive landing rate are more for Polar,LEO and ISS.
#
# However, for GTO, it's difficult to distinguish between successful and unsuccessful landings as both outcomes are present.

# %%
sns.catplot(y="Orbit", x="PayloadMass", hue="Class", data=df, aspect = 5)
plt.xlabel("Payload Mass",fontsize=20)
plt.ylabel("Orbit",fontsize=20)
plt.grid()
plt.show()

# %% [markdown]
# ### TASK 6: Visualize the launch success yearly trend

# %% [markdown]
# You can plot a line chart with x axis to be <code>Year</code> and y axis to be average success rate, to get the average launch success trend.

# %%
import datetime
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['Year'] = df['Date'].dt.year

# %%
df.head()
# Out:
#    FlightNumber       Date BoosterVersion  PayloadMass Orbit    LaunchSite  \
# 0             1 2010-06-04       Falcon 9  6104.959412   LEO  CCAFS SLC 40
# 1             2 2012-05-22       Falcon 9   525.000000   LEO  CCAFS SLC 40
# 2             3 2013-03-01       Falcon 9   677.000000   ISS  CCAFS SLC 40
# 3             4 2013-09-29       Falcon 9   500.000000    PO   VAFB SLC 4E
# 4             5 2013-12-03       Falcon 9  3170.000000   GTO  CCAFS SLC 40
#
#        Outcome  Flights  GridFins  Reused   Legs LandingPad  Block  \
# 0    None None        1     False   False  False        NaN    1.0
# 1    None None        1     False   False  False        NaN    1.0
# 2    None None        1     False   False  False        NaN    1.0
# 3  False Ocean        1     False   False  False        NaN    1.0
# 4    None None        1     False   False  False        NaN    1.0
#
#    ReusedCount Serial   Longitude   Latitude  Class  Year
# 0            0  B0003  -80.577366  28.561857      0  2010
# 1            0  B0005  -80.577366  28.561857      0  2012
# 2            0  B0007  -80.577366  28.561857      0  2013
# 3            0  B1003 -120.610829  34.632093      0  2013
# 4            0  B1004  -80.577366  28.561857      0  2013

# %%
success_trend  = df.groupby('Year')['Class'].mean().reset_index()
success_trend
# Out:
#    Year     Class
# 0  2010  0.000000
# 1  2012  0.000000
# 2  2013  0.000000
# 3  2014  0.333333
# 4  2015  0.333333
# 5  2016  0.625000
# 6  2017  0.833333
# 7  2018  0.611111
# 8  2019  0.900000
# 9  2020  0.842105

# %%
sns.lineplot(data=success_trend, x='Year', y='Class', color = 'orange', marker='D')
plt.ylabel('Success rate')
plt.xticks(range(2010, 2021))
# Out:
# ([<matplotlib.axis.XTick at 0x264e95c7d90>,
#   <matplotlib.axis.XTick at 0x264e960e350>,
#   <matplotlib.axis.XTick at 0x264e960ead0>,
#   <matplotlib.axis.XTick at 0x264e960f250>,
#   <matplotlib.axis.XTick at 0x264e960f9d0>,
#   <matplotlib.axis.XTick at 0x264e9648190>,
#   <matplotlib.axis.XTick at 0x264e9648910>,
#   <matplotlib.axis.XTick at 0x264e9649090>,
#   <matplotlib.axis.XTick at 0x264e960e0d0>,
#   <matplotlib.axis.XTick at 0x264e9668b90>,
#   <matplotlib.axis.XTick at 0x264e9669310>],
#  [Text(2010, 0, '2010'),
#   Text(2011, 0, '2011'),
#   Text(2012, 0, '2012'),
#   Text(2013, 0, '2013'),
#   Text(2014, 0, '2014'),
#   Text(2015, 0, '2015'),
#   Text(2016, 0, '2016'),
#   Text(2017, 0, '2017'),
#   Text(2018, 0, '2018'),
#   Text(2019, 0, '2019'),
#   Text(2020, 0, '2020')])

# %% [markdown]
# ## Features Engineering

# %% [markdown]
# By now, you should obtain some preliminary insights about how each important variable would affect the success rate, we will select the features that will be used in success prediction in the future module.

# %%
features = df[['FlightNumber', 'PayloadMass', 'Orbit', 'LaunchSite', 'Flights', 'GridFins', 'Reused', 'Legs', 'LandingPad', 'Block', 'ReusedCount', 'Serial']]
features.head()
# Out:
#    FlightNumber  PayloadMass Orbit    LaunchSite  Flights  GridFins  Reused  \
# 0             1  6104.959412   LEO  CCAFS SLC 40        1     False   False
# 1             2   525.000000   LEO  CCAFS SLC 40        1     False   False
# 2             3   677.000000   ISS  CCAFS SLC 40        1     False   False
# 3             4   500.000000    PO   VAFB SLC 4E        1     False   False
# 4             5  3170.000000   GTO  CCAFS SLC 40        1     False   False
#
#     Legs LandingPad  Block  ReusedCount Serial
# 0  False        NaN    1.0            0  B0003
# 1  False        NaN    1.0            0  B0005
# 2  False        NaN    1.0            0  B0007
# 3  False        NaN    1.0            0  B1003
# 4  False        NaN    1.0            0  B1004

# %% [markdown]
# ### TASK  7: Create dummy variables to categorical columns

# %% [markdown]
# Use the function <code>get_dummies</code> and <code>features</code> dataframe to apply OneHotEncoder to the column <code>Orbits</code>, <code>LaunchSite</code>, <code>LandingPad</code>, and <code>Serial</code>. Assign the value to the variable <code>features_one_hot</code>, display the results using the method head. Your result dataframe must include all features including the encoded ones.

# %%
# HINT: Use get_dummies() function on the categorical columns
features_one_hot = pd.get_dummies(features[['Orbit', 'LaunchSite', 'LandingPad', 'Serial']])
features_F = pd.concat([features, features_one_hot], axis=1)

# %%
features_F.drop(columns=['Orbit', 'LaunchSite', 'LandingPad', 'Serial'], inplace=True)

# %%
features_one_hot = features_F.astype('float32')

# %%
features_one_hot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 80 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   FlightNumber                         90 non-null     float32
#  1   PayloadMass                          90 non-null     float32
#  2   Flights                              90 non-null     float32
#  3   GridFins                             90 non-null     float32
#  4   Reused                               90 non-null     float32
#  5   Legs                                 90 non-null     float32
#  6   Block                                90 non-null     float32
#  7   ReusedCount                          90 non-null     float32
#  8   Orbit_ES-L1                          90 non-null     float32
#  9   Orbit_GEO                            90 non-null     float32
#  10  Orbit_GTO                            90 non-null     float32
#  11  Orbit_HEO                            90 non-null     float32
#  12  Orbit_ISS                            90 non-null     float32
#  13  Orbit_LEO                            90 non-null     float32
#  14  Orbit_MEO                            90 non-null     float32
#  15  Orbit_PO                             90 non-null     float32
#  16  Orbit_SO                             90 non-null     float32
#  17  Orbit_SSO                            90 non-null     float32
#  18  Orbit_VLEO                           90 non-null     float32
#  19  LaunchSite_CCAFS SLC 40              90 non-null     float32
#  20  LaunchSite_KSC LC 39A                90 non-null     float32
#  21  LaunchSite_VAFB SLC 4E               90 non-null     float32
#  22  LandingPad_5e9e3032383ecb267a34e7c7  90 non-null     float32
#  23  LandingPad_5e9e3032383ecb554034e7c9  90 non-null     float32
#  24  LandingPad_5e9e3032383ecb6bb234e7ca  90 non-null     float32
#  25  LandingPad_5e9e3032383ecb761634e7cb  90 non-null     float32
#  26  LandingPad_5e9e3033383ecbb9e534e7cc  90 non-null     float32
#  27  Serial_B0003                         90 non-null     float32
#  28  Serial_B0005                         90 non-null     float32
#  29  Serial_B0007                         90 non-null     float32
#  30  Serial_B1003                         90 non-null     float32
#  31  Serial_B1004                         90 non-null     float32
#  32  Serial_B1005                         90 non-null     float32
#  33  Serial_B1006                         90 non-null     float32
#  34  Serial_B1007                         90 non-null     float32
#  35  Serial_B1008                         90 non-null     float32
#  36  Serial_B1010                         90 non-null     float32
#  37  Serial_B1011                         90 non-null     float32
#  38  Serial_B1012                         90 non-null     float32
#  39  Serial_B1013                         90 non-null     float32
#  40  Serial_B1015                         90 non-null     float32
#  41  Serial_B1016                         90 non-null     float32
#  42  Serial_B1017                         90 non-null     float32
#  43  Serial_B1018                         90 non-null     float32
#  44  Serial_B1019                         90 non-null     float32
#  45  Serial_B1020                         90 non-null     float32
#  46  Serial_B1021                         90 non-null     float32
#  47  Serial_B1022                         90 non-null     float32
#  48  Serial_B1023                         90 non-null     float32
#  49  Serial_B1025                         90 non-null     float32
#  50  Serial_B1026                         90 non-null     float32
#  51  Serial_B1028                         90 non-null     float32
#  52  Serial_B1029                         90 non-null     float32
#  53  Serial_B1030                         90 non-null     float32
#  54  Serial_B1031                         90 non-null     float32
#  55  Serial_B1032                         90 non-null     float32
#  56  Serial_B1034                         90 non-null     float32
#  57  Serial_B1035                         90 non-null     float32
#  58  Serial_B1036                         90 non-null     float32
#  59  Serial_B1037                         90 non-null     float32
#  60  Serial_B1038                         90 non-null     float32
#  61  Serial_B1039                         90 non-null     float32
#  62  Serial_B1040                         90 non-null     float32
#  63  Serial_B1041                         90 non-null     float32
#  64  Serial_B1042                         90 non-null     float32
#  65  Serial_B1043                         90 non-null     float32
#  66  Serial_B1044                         90 non-null     float32
#  67  Serial_B1045                         90 non-null     float32
#  68  Serial_B1046                         90 non-null     float32
#  69  Serial_B1047                         90 non-null     float32
#  70  Serial_B1048                         90 non-null     float32
#  71  Serial_B1049                         90 non-null     float32
#  72  Serial_B1050                         90 non-null     float32
#  73  Serial_B1051                         90 non-null     float32
#  74  Serial_B1054                         90 non-null     float32
#  75  Serial_B1056                         90 non-null     float32
#  76  Serial_B1058                         90 non-null     float32
#  77  Serial_B1059                         90 non-null     float32
#  78  Serial_B1060                         90 non-null     float32
#  79  Serial_B1062                         90 non-null     float32
# dtypes: float32(80)
# memory usage: 28.3 KB

# %%
features_one_hot.to_csv('dataset_part_3.csv', index=False)

# %%
features_one_hot.shape
# Out:
# (90, 80)
